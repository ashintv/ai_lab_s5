# %%
def find_next_node(start,curr):
    shortest=9999
    print(curr)
    for neighbour in graph[start]:
        print('---------',neighbour,' with astar cost',heuristic[neighbour]+curr,'curr sum is',curr)
        if heuristic[neighbour]+curr+graph[start][neighbour] < shortest and neighbour not in visited:
            next_way = neighbour
            shortest = heuristic[next_way]+curr+graph[start][neighbour]
            print('------- finding next ',next_way,shortest)

    visited.add(next_way)
    print(visited)
    if heuristic[next_way]==0:
        return next_way,True,shortest
    return next_way,False,shortest
 

def a_star_bfs(next_node):
    path = [next_node]
    path_find = False
    curr = 0
    visited = set()
    visited.add(next_node)
    while not path_find:
        print('------------------------------------------------------------------')
        next_node,path_find,curr= find_next_node(next_node,curr)
        print('selected node ',next_node,curr, curr+graph[path[-1]][next_node])
        if next_node is None:
            print('No path')
            break
        path.append(next_node)
        visited.add(next_node)
    print(path)
    


graph = {
    'A': {'B': 1, 'C': 4},
    'B': {'A': 1, 'C': 2, 'D': 5},
    'C': {'A': 4, 'B': 2, 'D': 1},
    'D': {'B': 5, 'C': 1, 'E': 3},
    'E': {'D': 3, 'F': 2},
    'F': {'E': 2}
}
heuristic = {
    'A': 7,
    'B': 6,
    'C': 2,
    'D': 1,
    'E': 0,  # Goal node
    'F': 3
}
visited = set()
a_star_bfs('A')
# Out:
# ------------------------------------------------------------------
# 0
# --------- B  with astar cost 6 curr sum is 0
# ------- finding next  B 7
# --------- C  with astar cost 2 curr sum is 0
# ------- finding next  C 6
# {'C'}
# selected node  C 6 10
# ------------------------------------------------------------------
# 6
# --------- A  with astar cost 13 curr sum is 6
# ------- finding next  A 17
# --------- B  with astar cost 12 curr sum is 6
# ------- finding next  B 14
# --------- D  with astar cost 7 curr sum is 6
# ------- finding next  D 8
# {'D', 'C'}
# selected node  D 8 9
# ------------------------------------------------------------------
# 8
# --------- B  with astar cost 14 curr sum is 8
# ------- finding next  B 19
# --------- C  with astar cost 10 curr sum is 8
# --------- E  with astar cost 8 curr sum is 8
# ------- finding next  E 11
# {'D', 'E', 'C'}
# selected node  E 11 14
# ['A', 'C', 'D', 'E']
